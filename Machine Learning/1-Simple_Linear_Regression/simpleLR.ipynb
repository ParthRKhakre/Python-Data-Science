# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placemen.csv')

# %%
df.head()
# Out:
#    gpa  package
# 0  5.1      3.4
# 1  5.3      3.1
# 2  5.5      3.8
# 3  5.7      3.6
# 4  5.9      4.0

# %%
plt.scatter(df['gpa'],df['package'])
plt.xlabel('GPA')
plt.ylabel('Package in lpa')
# Out:
# Text(0, 0.5, 'Package in lpa')
