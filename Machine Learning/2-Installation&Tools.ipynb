# %% [markdown]
# # Anaconda - Its a platform for Data Science
# > It provides features like - Spyder, Jupyter Notebook

# %% [markdown]
# # Creating Virtual Environment
# If not informed we every platform(jupyter notebook,etc) provide us some basic pre-installed package that are used more frequently
