# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of the symbols that are considered to be the correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code.
#
# Semantics refers to the meaning or the interpretations of the symbols,characters and commands in a language It is about what the code is supposed to do when it runs

# %%
# Basic Syntax rules in python
# Case Sensitivity - Python is case sensitive

name = "Parth"
Name = "Khakre"

print(name)
print(Name) 

# Both the variable are different due to case sensitivity
# Out:
# Parth
# Khakre

# %% [markdown]
# # Indentation
# Indentation in python is used to define the structure and hierarchy of the code.
# Unlike many other languages that use braces{} to delimit blocks of code, Python uses indentation to determine the grouping of the statements.This means that all the statements within the block must be indented at the same level

# %%
# Indentation
# Python uses indentation to define blocks of code.
# Consistent use of spaces (commonly 4) or tab is required.

age = 32
if age>30:
    print("Yes Vote")
    
else:
    print(f"No Vote After: {18 - age}")
# Out:
# Yes Vote

# %%
# this is single line comments
print("Hello Parth")
# Out:
# Hello Parth

# %%
# Line Continuation 
# Use a backslash(\) to continue a statement to the next line
total = 1+2+3+4+\
    5+6+7+8+9
    
print(total)
# Out:
# 45

# %%
# Multiple statements on single line
x = 5; y = 10; z=x+y
print(z)
# Out:
# 15

# %%
# Understanding Semantics In Python
# Variable assignment
age = 32 # Integer

# age is an integer and kernel will 
# automatically understand datatype 
# during runtime

name = "Parth" # String
# Out:
# str

# %%
type(age)
type(name)

# %%
# Type Inference - python assigns the datatype of 
# the variable during runtime this is known as dynamic nature 

variable = 10
print(type(variable))
variable = "Parth"
print(type(variable))
# Above example shows the dynamic nature datatype changed from int to string
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Name Error 
# assigning a variable to another varible that's not initialize
a = b

# %%
# Code Example 
if True:
    print("Correct Indentation")
    if False:
        print("This not print")
    print("This will print")    
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
