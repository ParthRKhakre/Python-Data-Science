# %% [markdown]
# # OOP's
# * Object Oriented Programming is a programming paradiagm use to create software
#
# * Everything in python is an object
#
# # The Problem
# * procedural programming results into application being complex and prone to code blast
#
# # Solution to Above problem is
# * Generality(procedural) to Specificity(modularity)
#
# * OOP gives programmer power to create Custom Datatype
#
# # Object Oriented Programming
# * Object
# * Class
# * Abstraction
# * Polymorphism
# * Encapsulation
# * Inheritance

# %% [markdown]
# # Class
# * are like blueprint overwhich object can be created
# * All the datatype list,tuple,set all are classes
# * Class is set of rules that Object Follows
#
# Types of classes in python are :
# 1) Built-in Class
# 2) User Defined Class
#
# > Class Contains the following :
# > * Data or Property
# > * Functions or Behaviour

# %%
# Syntax for class
# class name:
    # attributes
    # ----------
    
    # functionalities
    # ----------
    
class Car:
    color = 'Blue'
    model = 'G-Series'
    
    def total_avg(km,time):
        return km/time

# %% [markdown]
# # Object
# * is instance of class
# * are implementation of class is real world
# * Object are Real World Entity

# %%
# Syntax to create object 
# object_name = className()

BMW = Car()

# %% [markdown]
# # ATM Machine Code

# %%
class Atm:
    
    # constructor - special function present inside the class
    # In order to execute the function there is no need to call it explicitly
    # Whenever Object is created Constructor is called
    def __init__(self):
        print(id(self))
        self.pin =''
        self.balance = 0
        # self.menu()
        
    # Rule: Whenever you want to create a variable create it inside the class constructor
    # while creating variable use self keyword
    # Until and unless you create a object of class the code of class have no meaning  
    
    def menu(self):
        user_input = input('''
              Hi How Can I Help You 
              1.Press 1 to create pin
              2.Press 2 to change pin
              3.Press 3 to check balance
              4.Press 4 to Withdraw
              5.Anything else to exit              
              ''')
        if user_input == '1':
            # create pin
            self.create_pin()
        elif user_input == '2':
            self.change_pin()
        elif user_input == '3':
            # check balance
            self.check_balance()
        elif user_input == '4':
            # Withdrawal
            self.withdrawal();
        else:
            # Exit
            exit()
            
    def create_pin(self):
        user_pin = input("Enter Your Pin:") 
        self.pin = user_pin
        
        user_balance = int(input("Enter Your Balance:"))
        self.balance = user_balance
        print("PIN Created Successfully!")
        self.menu()
        
    def change_pin(self):
        old_pin = input('Enter Old PIN:')
        if old_pin == self.pin:
            new_pin = input("Enter PIN: ")
            self.pin = new_pin 
            print('PIN Changed Successfully')
            self.menu()
        else:
            print("Invalid Existing Pin")  
            self.menu()  
     
    def check_balance(self):
        pin = input("Enter Your PIN")
        if pin == self.pin:
           print(self.balance)
           self.menu()
        else:
            print('Enter Correct PIN') 
            self.menu()
            
    def withdrawal(self):
        user_pin = input("Enter PIN:")
        if user_pin == self.pin:
            amount = int(input("Enter the Withdrawal Amount: "))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print("Withdrawal Successful Current Balance",self.balance)
                self.menu()
            else:
                print("Insufficient Balance")        
        else:
            print("Incorrect PIN!")

# %%
# Created an object of Atm Class
person = Atm()
# Out:
# 1776164862192

# %%
print(type(person))
print(person.balance)
print(person.pin)
# Out:
# <class '__main__.Atm'>
# 0

# %% [markdown]
# # Methods Vs Functions
# * function present inside class is called as method
# * function present outside class is called as function

# %%
L = [1,2,3,4]
len(L)          # len() is function outside the list class
L.append(5)     # .append() is method as it is written inside the list class

# %% [markdown]
# # Magic Methods(Dunder Methods)
# * are special methods each method have some superpower(e.g. Constructor)
#
# > Syntax for Magic Methods:
# > __ name __
#
# > Example :
# > __ init() __ Constructor

# %% [markdown]
# # Constructor
# it is a Methods it automatically get called/Triggered when an instance of class is created
#
# # Why Constructor
# * Normal methods are triggered when user wanted them to be triggered
# * Constructor executed when program starts so we put configuration related function inside the Constructor
# * name of constructor cannot be renamed.

# %% [markdown]
# # Why Do We Need Self
#
# * Golden Rule : Class(are Rules) that Object follow the Rules. Class members can only be access using the object of that class.
# * Not even the function of class itself can called another function of same class.
# * In order to make this possible we use "self" keyword

# %% [markdown]
# # self keyword

# %%
# Address of self 
atm = Atm()
# Out:
# 1776165138944

# %%
# Address of atm object
print(id(atm))
# Out:
# 1776165138944

# %% [markdown]
# > from above example we get to know that atm and self are point to the same memory address from these we get to know that self and object are same
#
# * Whenever an object of the class is created self is replace with object variable

# %% [markdown]
# # Fraction Datatype

# %%
class Fraction:
    
    # Parameterized Constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num * other.den + other.num * self.den 
        new_den = self.den * other.den
        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self, other):
        new_num = self.num * other.den - other.num * self.den 
        new_den = self.den * other.den
        return '{}/{}'.format(new_num,new_den)  
    
    def __mul__(self, other):
        new_num = self.num * other.num 
        new_den = self.den * other.den
        return '{}/{}'.format(new_num,new_den)
    
    def __truediv__(self, other):
        new_num = self.num * other.den 
        new_den = self.den * other.num
        return '{}/{}'.format(new_num,new_den)

# %%
frac1 = Fraction(3,4)
frac2 = Fraction(1,2)
print(frac1 / frac2)
# Out:
# 6/4

# %% [markdown]
# # def __ str __(self)
# > is a special function method that define how object is represented as an informal human readable string
#
# > print function internally uses str class when ever anything inside the print is executed it calls the str()function.

# %% [markdown]
# # def __ add __(self)
# > is a special function in python that customizes the behaviour of the addition operator for custom class

# %% [markdown]
# # Write OOP classes to handle the following scenarios
#
# * A user can create and view 2D Co-ordinates
# * A user can find out the distance between 2 Co Ordinates
# * A user can find the distance of a coordinate from origin
# * A user can check if a point lies on a given line
# * A user can find the distance between a given 2D point and a given line

# %%
import math

class coordinate:
    def __init__(self,x,y):
        self.x = x
        self.y = y
     
    # View Coordinates   
    def __str__(self):
        return '({},{})'.format(self.x,self.y)   
        
    def EuclideanDistance(self,other):
        x = (self.x - other.x)**2    
        y = (self.y - other.y)**2
        sum = x + y
        return math.sqrt(sum)
    
    def distancefromOrigin(self):
        sum = (self.x)**2 + (self.y)**2
        return math.sqrt(sum)

class line:   
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
        
    # View Of Line
    def __str__(self):
        return '{}x + {}y + {} == 0'.format(self.A,self.B,self.C)    
    
    def check_lies_or_not(line,point):
        if line.A * point.x + line.B * point.y + line.C  == 0:
            return 'Lies on the line'
        else:
            return 'Does not lies on the line'
        
    def shortest_distance(line,point):
        return abs(line.A * point.x + line.B * point.y + line.C) /  math.sqrt(line.A**2 + line.B**2)

# create a method in line class to check whether two lines intersect or not
         
line1 = line(9,8,5)      
point1 = coordinate(9,8)
point2 = coordinate(9,10)    
print(line1.shortest_distance(point1))
# Out:
# 12.456821978060995
