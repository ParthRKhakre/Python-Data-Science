# %% [markdown]
# # Conditional Statements (if,elif,else)

# %%
# if statement - evaluate condition and execute block of code accordingly
age = 20
if age >= 18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the elections

# %%
# else statment executes a block of code if the condition in the if block is false
age=16

if age>=18:
    print("You are allowed to vote")
else:
    print("You are minor")
# Out:
# You are minor

# %%
# elif statement allows you to check multiple conditions. It stands for "else if"
age = 20

if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")  
else:
    print("You are a adult")
# Out:
# You are a adult

# %%
# Nested Conditional Statements
# you can place one or more if,elif, or else statements inside another if,elif or else statement to create a nested conditionals statements 

# number tell is negative and is it even or odd 

num = int(input("Enter num:"))

if num<0:
    print(num,"is negative")
    if num % 2 == 0:
        print(num,"is even")
    else:
        print(num,"is Odd")  
else:
    print(num,"is positive")
    if num % 2 == 0:
        print(num,"is even")
    else:
        print(num,"is Odd")
# Out:
# 123 is positive
# 123 is Odd

# %%
# Use Cases
# Determine whether a year is a leap year or not
year = int(input("Enter the year: "))

if year%4==0:
    if year%100!=0 or year%400==0:
     print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2021 is not a leap year

# %%
# determine the ticket price based on the age and whether the person is a student.
# Ticket pricing based on the age and students status

age = int(input("Enter age : "))
is_student = input("Are you a student? (yes/no)").lower()

# Determine ticket price
if age < 5:
    price="Free"
elif age <= 12:
    price="$10"
elif age <= 17:
    if is_student == 'yes':
        price = '$12'
    else:
        price='$15'
elif age<=64:
    if is_student == 'yes':
        price = '$18'
    else:
        price = '$25'
