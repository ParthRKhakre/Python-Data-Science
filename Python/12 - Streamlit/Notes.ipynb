# %% [markdown]
# # Streamlit - Fast Way to build and share data apps
#
# * is an open-source Python library designed to help data scientists and AI/ML engineers create, share, and deploy interactive web applications quickly and easily

# %%
# Install Streamlit

# %% [markdown]
# # Text Utility

# %%
# title()
