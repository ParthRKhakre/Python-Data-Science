# %% [markdown]
# # Function in Python
# * it is a block of code that performs some operations
# * it increases code readability
#
# # Principal Of Function
# * Abstraction - hide internal complexities
# * Decomposition

# %%
# Syntax
# def name(arguments):
# ''' Doc string '''
#     // Code
#    return value  // Something you want to return

# %% [markdown]
# # Creating a function (with docstring)

# %%
def is_even(num):
    '''
    function returns if input is even or odd
    input: valid integer
    output: even/odd
    created on - 11 Jan
    '''
    if num % 2 == 0:
        return 'even'
    else :
        return 'odd'
