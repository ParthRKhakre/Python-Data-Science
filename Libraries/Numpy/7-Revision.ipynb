# %% [markdown]
# # Numpy
# is a fundamental library for scientific computing in python.
# It provides support for array and matrices, along with  a collection of mathematical functions to operate on these data structures. In the lesson, we will cover the basics of Numpy focusing on arrays and vectorized operations

# %%
# creating a numpy environment
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# create arrays using numpy 

# 1D
arr1 = np.array([1,2,3,4,5])
print(arr1)
print(type(arr1))  # np.array 
print(arr1.shape)  # shape give dimension of the array
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# (5,)

# %%
a2 = np.array([1,2,3,4,5,6])
a2.reshape(2,3) # (rows,columns)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
